# %%
# Out:
# ✅ Task Categorizer ready!
#
# ...
#   🧪 SAMPLE CATEGORIZATIONS
# ...
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   🔴  TASK CATEGORIZED
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Task      : EMERGENCY: Someone is having a seizure at the drop-in center...
#   Category  : 🚨 URGENT — Needs immediate attention!
#   Confidence: 100.0%
#
#   📊 Score Breakdown:
#   🔴 Urgent    ████████████████████ 100.0%
#   🟡 Mid-Level ░░░░░░░░░░░░░░░░░░░░ 0.0%
#   🟢 Low-Level ░░░░░░░░░░░░░░░░░░░░ 0.0%
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   🟡  TASK CATEGORIZED
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Task      : Please review the grant application before the end of the we...
#   Category  : ⚠️  MID-LEVEL — Should be handled soon.
#   Confidence: 100.0%
#
#   📊 Score Breakdown:
#   🔴 Urgent    ░░░░░░░░░░░░░░░░░░░░ 0.0%
# ...
